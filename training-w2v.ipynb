# %%
# !git clone https://github.com/Askoro1/w2v_from_scratch
# Out:
# Cloning into 'w2v_from_scratch'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 17 (delta 8), reused 13 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (17/17), 4.72 KiB | 1.18 MiB/s, done.
# Resolving deltas: 100% (8/8), done.

# %%
# %cd w2v_from_scratch
# Out:
# /kaggle/working/w2v_from_scratch

# %%
# !pip install -r requirements.txt

# %%
# !python w2v.py
# Out:
# README.md: 10.5kB [00:00, 21.6MB/s]
# ...
# wikitext-103-raw-v1/test-00000-of-00001.(…): 100%|█| 733k/733k [00:00<00:00, 2.3
# wikitext-103-raw-v1/train-00000-of-00002(…): 100%|█| 157M/157M [00:01<00:00, 104
# wikitext-103-raw-v1/train-00001-of-00002(…): 100%|█| 157M/157M [00:01<00:00, 155
# wikitext-103-raw-v1/validation-00000-of-(…): 100%|█| 657k/657k [00:00<00:00, 3.5
# Generating test split: 100%|██████| 4358/4358 [00:00<00:00, 62199.58 examples/s]
# Generating train split: 100%|█| 1801350/1801350 [00:02<00:00, 680525.96 examples
# Generating validation split: 100%|█| 3760/3760 [00:00<00:00, 452021.64 examples/
# Building corpus + vocab...
# 100%|██████████████████████████████| 1801350/1801350 [01:33<00:00, 19250.21it/s]
# Built corpus + vocab
# Filtering rare words...
# Filtered rare words
# Subsampling...
# Performed subsampling
# Deleting out-of-vocab tokens
# 100%|██████████████████████████████| 1801350/1801350 [00:20<00:00, 85864.26it/s]
# Deleted all out-of-vocab tokens
# ...
